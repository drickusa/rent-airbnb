# %%
# %sql
--Select count(1), longitude, latitude
--from rentalproperty.bronze.rentals
--group by longitude, latitude
--having count(1) > 1 
Select * from rentalproperty.bronze.rentals
where longitude = 5.671673 and latitude = 50.860841

# %%
# %sql
Select Distinct crawlStatus
 from rentalproperty.bronze.rentals

# %%
# %sql
Select count(1), deposit 
from rentalproperty.bronze.rentals GROUP BY deposit

# %%
# %sql
Select count(1), registrationCost 
from rentalproperty.bronze.rentals GROUP BY registrationCost

# %%
# %sql
Select * 
from rentalproperty.bronze.airbnb limit 10

# %%
# %sql
Select * From rentalproperty.silver.airbnb limit 10

# %%
# %sql
Select * From rentalproperty.silver.rentals limit 10
